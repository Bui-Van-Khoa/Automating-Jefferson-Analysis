# %%
import sys
sys.path.append(r'/kaggle/input/transcription')

# %%
import shutil

shutil.copy(r'/kaggle/input/transcription/requirements.txt', '/kaggle/working/')
# Out:
# '/kaggle/working/requirements.txt'

# %%
# Download
# !wget https://github.com/audeering/opensmile/releases/download/v3.0.2/opensmile-3.0.2-linux-x86_64.zip

# Extract
# !unzip opensmile-3.0.2-linux-x86_64.zip

# %%
from install_requirements import install_requirements

install_requirements()

# %%
from Pipeline import Jefferson_Transcription

# %%
# !ls
# !ls opensmile-3.0.2-linux-x86_64
# !chmod +x opensmile-3.0.2-linux-x86_64/bin/SMILExtract

# !./opensmile-3.0.2-linux-x86_64/bin/SMILExtract \
  -C opensmile-3.0.2-linux-x86_64/config/prosody/prosodyShs.conf \
  -I /kaggle/input/transcription/twos.wav \
  -O twos_pitch.csv
# Out:
# opensmile-3.0.2-linux-x86_64	  requirements.txt
# opensmile-3.0.2-linux-x86_64.zip
# bin	      config  example-audio  LICENSE   README.md
# CHANGELOG.md  doc     include	     licenses  scripts
# (MSG) [2] SMILExtract: openSMILE starting!
# (MSG) [2] SMILExtract: config file is: opensmile-3.0.2-linux-x86_64/config/prosody/prosodyShs.conf
# (MSG) [2] cComponentManager: successfully registered 102 component types.
# (MSG) [2] instance 'lldcsvsink': No filename given, disabling this sink component.
# (MSG) [2] instance 'lldarffsink': No filename given, disabling this sink component.
# (MSG) [2] cComponentManager: successfully finished createInstances (13 component instances were finalised, 1 data memories were finalised)
# (MSG) [2] cComponentManager: starting single thread processing loop
# (MSG) [2] cComponentManager: Processing finished! System ran for 4969 ticks.

# %%
# !ls
# Out:
# opensmile-3.0.2-linux-x86_64	  requirements.txt
# opensmile-3.0.2-linux-x86_64.zip  twos_pitch.csv

# %%
import pandas as pd

df = pd.read_csv("twos_pitch.csv", sep=';')

# %% [markdown]
# # New pipeline

# %%
transcriber = Jefferson_Transcription(
    wav_path=r"/kaggle/input/transcription/twos.wav",
    pitch_csv= r"/kaggle/input/transcription/twos_pitch.csv",
    hf_token="Token"
)


lines = transcriber.generate_full_annotation()

for line in lines:
    print(line)
# Out:
# Loading diarization model...
# config.yaml:   0%|          | 0.00/469 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/5.91M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/399 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/26.6M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/221 [00:00<?, ?B/s]
# Loading ASR model...
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.90k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.07k [00:00<?, ?B/s]
# ...

# %% [markdown]
# # Old pipeline

# %%
transcriber = Jefferson_Transcription(
    wav_path=r"/kaggle/input/main-audio/Data.wav",
    hf_token=""
)

transcriber.annotate_loudness()
transcriber.annotate_pitch()
lines = transcriber.generate_full_annotation()

for line in lines:
    print(line)
# Out:
# Loading diarization model...
# config.yaml:   0%|          | 0.00/469 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/5.91M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/399 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/26.6M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/221 [00:00<?, ?B/s]
# Loading ASR model...
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.90k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.07k [00:00<?, ?B/s]
# ...

# %%
transcriber = Jefferson_Transcription(
    wav_path=r"/kaggle/input/main-audio/Data.wav",
    noise_reduction=True,
    hf_token=""
)

transcriber.annotate_loudness()
lines = transcriber.generate_full_annotation()

for line in lines:
    print(line)
# Out:
# Performing noise reduction...
# /usr/local/lib/python3.11/dist-packages/df/io.py:9: UserWarning: `torchaudio.backend.common.AudioMetaData` has been moved to `torchaudio.AudioMetaData`. Please update the import path.
#   from torchaudio.backend.common import AudioMetaData
# 2025-06-10 18:03:27 | INFO     | DF | Running on torch 2.6.0+cu124
# 2025-06-10 18:03:27 | INFO     | DF | Running on host 3538a9acb8fe
# 2025-06-10 18:03:27 | INFO     | DF | Loading model settings of DeepFilterNet3
# 2025-06-10 18:03:27 | INFO     | DF | Using DeepFilterNet3 model at /root/.cache/DeepFilterNet/DeepFilterNet3
# 2025-06-10 18:03:27 | INFO     | DF | Initializing model `deepfilternet3`
# fatal: not a git repository (or any of the parent directories): .git
# 2025-06-10 18:03:28 | INFO     | DF | Found checkpoint /root/.cache/DeepFilterNet/DeepFilterNet3/checkpoints/model_120.ckpt.best with epoch 120
# 2025-06-10 18:03:28 | INFO     | DF | Running on device cuda:0
# ...
